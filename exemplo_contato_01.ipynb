# %%
import pandas as pd

data = {
    'empresa': ['Viagem e Turismo Ltda', 'Metalúrgica S.A.'],
    'cnpj': ['12345678000190', '98765432000101'],
    'meioContato': [
        {
            'contatos': [
                {
                    'id': 1,
                    'tipo': 'email',
                    'valor': 'email1@gmail.com',
                    'status': 'ativo', # Status do contato
                    'finalidades': [
                        {'nome': 'geral', 'status': 'ativo'},
                        {'nome': 'atendimento', 'status': 'ativo'}
                    ]
                },
                {
                    'id': 2,
                    'tipo': 'telefone',
                    'valor': '11988886666',
                    'status': 'ativo', # Status do contato
                    'finalidades': [
                        {'nome': 'comercial', 'status': 'ativo'}
                    ]
                },
                {
                    'id': 3,
                    'tipo': 'email',
                    'valor': 'email2@gmail.com',
                    'status': 'inativo', # Exemplo de contato inativo
                    'finalidades': [
                        {'nome': 'suporte', 'status': 'ativo'},
                        {'nome': 'marketing', 'status': 'inativo'}
                    ]
                },
                {
                    'id': 4,
                    'tipo': 'telefone',
                    'valor': '11988887777',
                    'status': 'ativo', # Status do contato
                    'finalidades': [
                        {'nome': 'suporte', 'status': 'ativo'},
                        {'nome': 'emergencia', 'status': 'ativo'}
                    ]
                },
                {
                    'id': 5,
                    'tipo': 'email',
                    'valor': 'email3@gmail.com',
                    'status': 'ativo', # Status do contato
                    'finalidades': [
                        {'nome': 'vendas', 'status': 'ativo'}
                    ]
                }
            ]
        },
        {
            'contatos': [
                {
                    'id': 6,
                    'tipo': 'telefone',
                    'valor': '11922221111',
                    'status': 'ativo', # Status do contato
                    'finalidades': [
                        {'nome': 'geral', 'status': 'ativo'}
                    ]
                },
                {
                    'id': 7,
                    'tipo': 'email',
                    'valor': 'email5@gmail.com',
                    'status': 'ativo', # Status do contato
                    'finalidades': [
                        {'nome': 'rh', 'status': 'ativo'}
                    ]
                },
                {
                    'id': 8,
                    'tipo': 'telefone',
                    'valor': '11922223333',
                    'status': 'inativo', # Exemplo de contato inativo
                    'finalidades': [
                        {'nome': 'financeiro', 'status': 'ativo'}
                    ]
                },
                {
                    'id': 9,
                    'tipo': 'email',
                    'valor': 'email6@gmail.com',
                    'status': 'ativo', # Status do contato
                    'finalidades': [
                        {'nome': 'compras', 'status': 'ativo'}
                    ]
                },
                {
                    'id': 10,
                    'tipo': 'telefone',
                    'valor': '11922224444',
                    'status': 'ativo', # Status do contato
                    'finalidades': [
                        {'nome': 'recepcao', 'status': 'ativo'}
                    ]
                }
            ]
        }
    ]
}

# Criando o DataFrame
df = pd.DataFrame(data)

print("DataFrame com status para cada contato e cada finalidade:")
print(df)
# Out:
# DataFrame com status para cada contato e cada finalidade:
#                  empresa            cnpj  \
# 0  Viagem e Turismo Ltda  12345678000190
# 1       Metalúrgica S.A.  98765432000101
#
#                                          meioContato
# 0  {'contatos': [{'id': 1, 'tipo': 'email', 'valo...
# 1  {'contatos': [{'id': 6, 'tipo': 'telefone', 'v...
